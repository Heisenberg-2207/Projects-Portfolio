# %% [markdown]
# ### Working Environment

# %% [markdown]
# ### Import Dataset

# %%
import pandas as pd

data = pd.read_csv('amazon_alexa.tsv', sep='\t')
data.head(10)
# Out:
#    rating       date             variation  \
# 0       5  31-Jul-18      Charcoal Fabric
# 1       5  31-Jul-18      Charcoal Fabric
# 2       4  31-Jul-18        Walnut Finish
# 3       5  31-Jul-18      Charcoal Fabric
# 4       5  31-Jul-18      Charcoal Fabric
# 5       5  31-Jul-18  Heather Gray Fabric
# 6       3  31-Jul-18     Sandstone Fabric
# 7       5  31-Jul-18      Charcoal Fabric
# 8       5  30-Jul-18  Heather Gray Fabric
# 9       5  30-Jul-18  Heather Gray Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1
# 5  I received the echo as a gift. I needed anothe...         1
# 6  Without having a cellphone, I cannot use many ...         1
# 7  I think this is the 5th one I've purchased. I'...         1
# 8                                        looks great         1
# 9  Love it! I’ve listened to songs I haven’t hear...         1

# %%
mydata = data[['verified_reviews','feedback']]
mydata.columns = ['review','label']

mydata.head()
# Out:
#                                               review  label
# 0                                      Love my Echo!      1
# 1                                          Loved it!      1
# 2  Sometimes while playing a game, you can answer...      1
# 3  I have had a lot of fun with this thing. My 4 ...      1
# 4                                              Music      1

# %%
mydata.value_counts('label')
# Out:
# label
# 1    2893
# 0     257
# Name: count, dtype: int64

# %%
# Count the occurrences of each label
label_counts = mydata["label"].value_counts()

# Get the number of rows to drop from the majority class
rows_to_drop = label_counts.max() - label_counts.min()

# Drop rows from the majority class randomly
if rows_to_drop > 0:
   data_majority = mydata[mydata["label"] == 1]
   data_balanced = mydata.drop(data_majority.sample(rows_to_drop).index)
else:
   data_balanced = mydata.copy()

# Check the new class balance
print(data_balanced["label"].value_counts())
# Out:
# label
# 1    257
# 0    257
# Name: count, dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
import re

def clean_text(text):

  #convert to string
  text = str(text)

  # Remove special characters and punctuation
  text = re.sub(r"[^\w\s]", " ", text)

  # Remove single characters
  text = re.sub(r"\b[a-zA-Z]\b", " ", text)

  # Remove HTML tags
  text = re.sub(r"<[^>]*>", " ", text)

  # Lowercase the text
  text = text.lower()

  # Remove extra whitespace
  text = re.sub(r"\s+", " ", text)

  # Trim leading and trailing spaces
  text = text.strip()

  return text

# %%
import pandas as pd

# Extract the review column as a list
reviews = data_balanced['review'].tolist()

# Clean the text in the list
cleaned_reviews = [clean_text(review) for review in reviews]

# Add the cleaned reviews as a new column to the DataFrame
data_balanced['clean_reviews'] = cleaned_reviews

# %%
data_balanced
# Out:
#                                                  review  label  \
# 8                                           looks great      1
# 13                                   Love, Love, Love!!      1
# 29                              Just like the other one      1
# 31                                            I like it      1
# 36    Love my Echo. Still learning all the things it...      1
# ...                                                 ...    ...
# 3091                                  I didn’t order it      0
# 3096  The product sounded the same as the emoji spea...      0
# 3110  Love it! I personally prefer Spotify music, so...      1
# 3136  I used it to control my smart home devices. Wo...      1
# 3137                                    Very convenient      1
#
#                                           clean_reviews
# 8                                           looks great
# 13                                       love love love
# 29                              just like the other one
# 31                                              like it
# 36    love my echo still learning all the things it ...
# ...                                                 ...
# 3091                                      didn order it
# 3096  the product sounded the same as the emoji spea...
# 3110  love it personally prefer spotify music so it ...
# 3136  used it to control my smart home devices works...
# 3137                                    very convenient
#
# [514 rows x 3 columns]

# %% [markdown]
# ## Data Split

# %%
import pandas as pd

# Assuming your DataFrame is called "df"
total_rows = len(data_balanced)
test_size = int(total_rows * 0.95)

# Randomly sample train_size rows for the training set
test_set = data_balanced.sample(test_size)

# Get the remaining rows for the test set
train_set = data_balanced.drop(test_set.index)

# %% [markdown]
# ## Sentiment w/ LLM

# %% [markdown]
# ### Setting up Gemini API

# %%
# !pip install -q -U google-generativeai

# %%
# Necessary packages
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Used to securely store your API key
from google.colab import userdata

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001-tuning

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
# %%time
response = model.generate_content("What is the meaning of life?")

to_markdown(response.text)
# Out:
# CPU times: user 142 ms, sys: 14.2 ms, total: 156 ms
# Wall time: 7.41 s
# > The meaning of life is a philosophical and existential question that has been pondered by humans for centuries. There is no one definitive answer, as the meaning of life is subjective and personal to each individual. Some people may find meaning in pursuing their passions, helping others, or creating a legacy. Others may find meaning in their relationships, their work, or their religious or spiritual beliefs. Ultimately, the meaning of life is something that each person must discover for themselves.
# >
# > According to Viktor Frankl, an Austrian neurologist, psychiatrist, philosopher, author, and Holocaust survivor, the meaning of life is to find meaning in one's life. He believed that people are motivated by a desire for meaning, and that finding meaning in life is essential for happiness and well-being. Frankl also believed that people can find meaning in life even in the most difficult circumstances, such as in the face of suffering and death.
# >
# > The Dalai Lama, the spiritual leader of Tibet, has said that the meaning of life is to be happy. He believes that happiness is not something that can be achieved through external possessions or circumstances, but rather something that comes from within. The Dalai Lama teaches that we can find happiness by practicing compassion, kindness, and forgiveness, and by living in harmony with nature and with ourselves.
# >
# > The meaning of life is a complex and multifaceted question, and there is no one definitive answer. However, by exploring our own values, beliefs, and experiences, we can each come to a deeper understanding of what makes life meaningful for us.

# %% [markdown]
# #### Single API Call

# %%
test_set_sample = test_set.sample(20)

test_set_sample['pred_label'] = ''

test_set_sample
# Out:
#                                                  review  label  \
# 2496                         My son loves his Echo Dot.      1
# 621   If you want to listen to music and have it com...      0
# 2653                                         I love it.      1
# 882   Really disappointed Alexa has to be plug-in to...      0
# 1602  Returned from repair with No repair done. It h...      0
# 2491  I reached out to Amazon, because the device wa...      0
# 375   Bought for my bathroom to listen when I'm in t...      1
# 388   Never could get it to work. A techie friend lo...      0
# 1537  It does not pick up my voice unless I yell mos...      1
# 759   I use it primarily to play music.  It works wo...      1
# 249   I have had all good experience, so far with th...      1
# 2000  received the wrong product...was so excited to...      0
# 2305  Had to return it as Hulu does not work on devi...      0
# 1285  Not happy with the Spot.  Reset numerous times...      0
# 1464  I love the echo show awesome speakers I love t...      1
# 1832  Got it specifically to work with the August Sm...      1
# 1473  Do not understand all the excitement over thes...      0
# 2365  I love the number of movies that are available...      1
# 499   Now I'm weary about these picking up conversat...      0
# 1558                                                         0
#
#                                           clean_reviews pred_label
# 2496                          my son loves his echo dot
# 621   if you want to listen to music and have it com...
# 2653                                            love it
# 882   really disappointed alexa has to be plug in to...
# 1602  returned from repair with no repair done it ha...
# 2491  reached out to amazon because the device wante...
# 375   bought for my bathroom to listen when in the s...
# 388   never could get it to work techie friend looke...
# 1537  it does not pick up my voice unless yell most ...
# 759   use it primarily to play music it works wonder...
# 249   have had all good experience so far with the s...
# 2000  received the wrong product was so excited to i...
# 2305  had to return it as hulu does not work on devi...
# 1285  not happy with the spot reset numerous times s...
# 1464  love the echo show awesome speakers love the f...
# 1832  got it specifically to work with the august sm...
# 1473  do not understand all the excitement over thes...
# 2365  love the number of movies that are available u...
# 499   now weary about these picking up conversations...
# 1558

# %%
# Convert the DataFrame to JSON using the to_json() method

json_data = test_set_sample[['clean_reviews','pred_label']].to_json(orient='records')

# Print the JSON data
print(json_data)
# Out:
# [{"clean_reviews":"my son loves his echo dot","pred_label":""},{"clean_reviews":"if you want to listen to music and have it come through several of the echo dot units simultaneously you must pay monthly fee thought this was amazon not apple ve paid for many of these so could have one in each room is that not enough of my money","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"really disappointed alexa has to be plug in to wall socket all the time my fault for not checking this but made the assumption that company has technologically advanced as amazon would sell this product with rechargeable battery if could return it would as my apple music and boom speaker give me more flexibility the alexa","pred_label":""},{"clean_reviews":"returned from repair with no repair done it has problem which requires it to be on for while for the defective part to show itself sent it for repair and got it back without being fixed the site gives no option to complain from the page have echo spot which works perfectly in the same position","pred_label":""},{"clean_reviews":"reached out to amazon because the device wanted to sync my phone number but it would not allow because it said my number was already in use customer service couldn help they basically told me to contact sprint to assist so echo does the bare minimum without access to my phone for set up so its kind of pointless to have and pay for","pred_label":""},{"clean_reviews":"bought for my bathroom to listen when in the shower love it","pred_label":""},{"clean_reviews":"never could get it to work techie friend looked at it for me and said the adapter wasn strong enough to power it and that it looked like it had been bought at dollar store so am going to replace the adapter and hope it works then","pred_label":""},{"clean_reviews":"it does not pick up my voice unless yell most times","pred_label":""},{"clean_reviews":"use it primarily to play music it works wonderfully still getting used to some of the many things it will do amazon has sent several tips since got it thanks for all your help","pred_label":""},{"clean_reviews":"have had all good experience so far with the second generation echo there are so many more things to learn but have not had the time yet right now am mostly enjoying the music weather updates using the alarm feature and her personality have also purchased some mini smart socket yes am very excited to begin using them","pred_label":""},{"clean_reviews":"received the wrong product was so excited to install it all excitement gone thank you amazon","pred_label":""},{"clean_reviews":"had to return it as hulu does not work on device it kept coming up with errors and hulu app not being able to open at times it was hit and miss and at times hulu will stop working right in the middle of show or movie plus fire stick is very slow in opening the apps","pred_label":""},{"clean_reviews":"not happy with the spot reset numerous times seems to be in slow mode have to be practically on top of it for it to hear me even after talking with support still do not have themes in the menu to choose from","pred_label":""},{"clean_reviews":"love the echo show awesome speakers love the fact when you listen to music the words come up all around liking it so far also being able to read what on your shopping list to do list and notifications","pred_label":""},{"clean_reviews":"got it specifically to work with the august smart lock and it connected to it with ease definitely ties the smart home together","pred_label":""},{"clean_reviews":"do not understand all the excitement over these alexa devices or the google ones either it rarely gets what say correct does not control the dish receiver yes set it up correctly using the alexa app on my phone we got this for 129 which is good deal ti is definately not worth the 229 price though maybe in another month it will get better or either have one that is just deaf and dumb really can not recommend this item at the current ti ...

# %%
prompt = f"""
You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
Customer reviews are provided between three back ticks.
In your output, only return the Json code back as output - which is provided between three backticks.
Your task is to update predicted labels under 'pred_label' in the Json code.
Don't make any changes to Json code format, please.

```
{json_data}
```
"""

print(prompt)
# Out:
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
# Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
# Customer reviews are provided between three back ticks.
# In your output, only return the Json code back as output - which is provided between three backticks.
# Your task is to update predicted labels under 'pred_label' in the Json code.
# Don't make any changes to Json code format, please.
#
# ```
# [{"clean_reviews":"my son loves his echo dot","pred_label":""},{"clean_reviews":"if you want to listen to music and have it come through several of the echo dot units simultaneously you must pay monthly fee thought this was amazon not apple ve paid for many of these so could have one in each room is that not enough of my money","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"really disappointed alexa has to be plug in to wall socket all the time my fault for not checking this but made the assumption that company has technologically advanced as amazon would sell this product with rechargeable battery if could return it would as my apple music and boom speaker give me more flexibility the alexa","pred_label":""},{"clean_reviews":"returned from repair with no repair done it has problem which requires it to be on for while for the defective part to show itself sent it for repair and got it back without being fixed the site gives no option to complain from the page have echo spot which works perfectly in the same position","pred_label":""},{"clean_reviews":"reached out to amazon because the device wanted to sync my phone number but it would not allow because it said my number was already in use customer service couldn help they basically told me to contact sprint to assist so echo does the bare minimum without access to my phone for set up so its kind of pointless to have and pay for","pred_label":""},{"clean_reviews":"bought for my bathroom to listen when in the shower love it","pred_label":""},{"clean_reviews":"never could get it to work techie friend looked at it for me and said the adapter wasn strong enough to power it and that it looked like it had been bought at dollar store so am going to replace the adapter and hope it works then","pred_label":""},{"clean_reviews":"it does not pick up my voice unless yell most times","pred_label":""},{"clean_reviews":"use it primarily to play music it works wonderfully still getting used to some of the many things it will do amazon has sent several tips since got it thanks for all your help","pred_label":""},{"clean_reviews":"have had all good experience so far with the second generation echo there are so many more things to learn but have not had the time yet right now am mostly enjoying the music weather updates using the alarm feature and her personality have also purchased some mini smart socket yes am very excited to begin using them","pred_label":""},{"clean_reviews":"received the wrong product was so excited to install it all excitement gone thank you amazon","pred_label":""},{"clean_reviews":"had to return it as hulu does not work on device it kept coming up with errors and hulu app not being able to open at times it was hit and miss and at times hulu will stop working right in the middle of show or movie plus fire stick is very slow in opening the apps","pred_label":""},{"clean_reviews":"not happy with the spot reset numerous times seems to be in slow mode have to be practically on top of it for it to hear me even after talking with support still do not have themes in the menu to choose from","pred_label":""},{"clean_reviews":"love the echo show awesome speakers love the fact when you listen to music the words come up all around liking it so far also being able to read what on your shopping list to do list and notifications","pred_label":""},{"clean_reviews":"got it specifically to work with the august smart lock and it connected to it with ease definitely ties the smart home together","pred_label":""},{"clean_reviews":"do not understand all the excitement over these alexa devices or the google ones either it rarely gets what say correct does not control the dish receiver yes set it up correctly using the alexa app on my phone we got this for 129 which is good deal ti is definately not worth the 229 price though maybe in another month it will get better or either have one that is just deaf and dumb really can not recommend this item at the current ti ...
# ```

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# ```
# [{"clean_reviews":"my son loves his echo dot","pred_label":1},{"clean_reviews":"if you want to listen to music and have it come through several of the echo dot units simultaneously you must pay monthly fee thought this was amazon not apple ve paid for many of these so could have one in each room is that not enough of my money","pred_label":0},{"clean_reviews":"love it","pred_label":1},{"clean_reviews":"really disappointed alexa has to be plug in to wall socket all the time my fault for not checking this but made the assumption that company has technologically advanced as amazon would sell this product with rechargeable battery if could return it would as my apple music and boom speaker give me more flexibility the alexa","pred_label":0},{"clean_reviews":"returned from repair with no repair done it has problem which requires it to be on for while for the defective part to show itself sent it for repair and got it back without being fixed the site gives no option to complain from the page have echo spot which works perfectly in the same position","pred_label":0},{"clean_reviews":"reached out to amazon because the device wanted to sync my phone number but it would not allow because it said my number was already in use customer service couldn help they basically told me to contact sprint to assist so echo does the bare minimum without access to my phone for set up so its kind of pointless to have and pay for","pred_label":0},{"clean_reviews":"bought for my bathroom to listen when in the shower love it","pred_label":1},{"clean_reviews":"never could get it to work techie friend looked at it for me and said the adapter wasn strong enough to power it and that it looked like it had been bought at dollar store so am going to replace the adapter and hope it works then","pred_label":0},{"clean_reviews":"it does not pick up my voice unless yell most times","pred_label":0},{"clean_reviews":"use it primarily to play music it works wonderfully still getting used to some of the many things it will do amazon has sent several tips since got it thanks for all your help","pred_label":1},{"clean_reviews":"have had all good experience so far with the second generation echo there are so many more things to learn but have not had the time yet right now am mostly enjoying the music weather updates using the alarm feature and her personality have also purchased some mini smart socket yes am very excited to begin using them","pred_label":1},{"clean_reviews":"received the wrong product was so excited to install it all excitement gone thank you amazon","pred_label":0},{"clean_reviews":"had to return it as hulu does not work on device it kept coming up with errors and hulu app not being able to open at times it was hit and miss and at times hulu will stop working right in the middle of show or movie plus fire stick is very slow in opening the apps","pred_label":0},{"clean_reviews":"not happy with the spot reset numerous times seems to be in slow mode have to be practically on top of it for it to hear me even after talking with support still do not have themes in the menu to choose from","pred_label":0},{"clean_reviews":"love the echo show awesome speakers love the fact when you listen to music the words come up all around liking it so far also being able to read what on your shopping list to do list and notifications","pred_label":1},{"clean_reviews":"got it specifically to work with the august smart lock and it connected to it with ease definitely ties the smart home together","pred_label":1},{"clean_reviews":"do not understand all the excitement over these alexa devices or the google ones either it rarely gets what say correct does not control the dish receiver yes set it up correctly using the alexa app on my phone we got this for 129 which is good deal ti is definately not worth the 229 price though maybe in another month it will get better or either have one that is just deaf and dumb really can not recommend this item at the current time","pred_label" ...
# ```

# %%
import json

# Clean the data by stripping the backticks
json_data = response.text.strip("`")

# Load the cleaned data and convert to DataFrame
data = json.loads(json_data)
df_sample = pd.DataFrame(data)

df_sample
# Out:
#                                         clean_reviews  pred_label
# 0                           my son loves his echo dot           1
# 1   if you want to listen to music and have it com...           0
# 2                                             love it           1
# 3   really disappointed alexa has to be plug in to...           0
# 4   returned from repair with no repair done it ha...           0
# 5   reached out to amazon because the device wante...           0
# 6   bought for my bathroom to listen when in the s...           1
# 7   never could get it to work techie friend looke...           0
# 8   it does not pick up my voice unless yell most ...           0
# 9   use it primarily to play music it works wonder...           1
# 10  have had all good experience so far with the s...           1
# 11  received the wrong product was so excited to i...           0
# 12  had to return it as hulu does not work on devi...           0
# 13  not happy with the spot reset numerous times s...           0
# 14  love the echo show awesome speakers love the f...           1
# 15  got it specifically to work with the august sm...           1
# 16  do not understand all the excitement over thes...           0
# 17  love the number of movies that are available u...           1
# 18  now weary about these picking up conversations...           0
# 19                                                              0

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_sample['pred_label'] = df_sample['pred_label'].values
test_set_sample
# Out:
#                                                  review  label  \
# 2496                         My son loves his Echo Dot.      1
# 621   If you want to listen to music and have it com...      0
# 2653                                         I love it.      1
# 882   Really disappointed Alexa has to be plug-in to...      0
# 1602  Returned from repair with No repair done. It h...      0
# 2491  I reached out to Amazon, because the device wa...      0
# 375   Bought for my bathroom to listen when I'm in t...      1
# 388   Never could get it to work. A techie friend lo...      0
# 1537  It does not pick up my voice unless I yell mos...      1
# 759   I use it primarily to play music.  It works wo...      1
# 249   I have had all good experience, so far with th...      1
# 2000  received the wrong product...was so excited to...      0
# 2305  Had to return it as Hulu does not work on devi...      0
# 1285  Not happy with the Spot.  Reset numerous times...      0
# 1464  I love the echo show awesome speakers I love t...      1
# 1832  Got it specifically to work with the August Sm...      1
# 1473  Do not understand all the excitement over thes...      0
# 2365  I love the number of movies that are available...      1
# 499   Now I'm weary about these picking up conversat...      0
# 1558                                                         0
#
#                                           clean_reviews  pred_label
# 2496                          my son loves his echo dot           1
# 621   if you want to listen to music and have it com...           0
# 2653                                            love it           1
# 882   really disappointed alexa has to be plug in to...           0
# 1602  returned from repair with no repair done it ha...           0
# 2491  reached out to amazon because the device wante...           0
# 375   bought for my bathroom to listen when in the s...           1
# 388   never could get it to work techie friend looke...           0
# 1537  it does not pick up my voice unless yell most ...           0
# 759   use it primarily to play music it works wonder...           1
# 249   have had all good experience so far with the s...           1
# 2000  received the wrong product was so excited to i...           0
# 2305  had to return it as hulu does not work on devi...           0
# 1285  not happy with the spot reset numerous times s...           0
# 1464  love the echo show awesome speakers love the f...           1
# 1832  got it specifically to work with the august sm...           1
# 1473  do not understand all the excitement over thes...           0
# 2365  love the number of movies that are available u...           1
# 499   now weary about these picking up conversations...           0
# 1558                                                              0

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix

y_true = test_set_sample["label"]
y_pred = test_set_sample["pred_label"]

confusion_matrix(y_true, y_pred)
# Out:
# array([[11,  0],
#        [ 1,  8]])

# %% [markdown]
# #### Batching API Calls (Single Shot)

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 2005  Why do we need to buy a $100 hub to get it to ...      0
# 2439  Seems to work ok, but no youtube tv?  Really? ...      0
# 2628                                                         0
# 1379  Bought the spot and loved it. Within months it...      0
# 1036                             Alexa hardly came on..      0
# ...                                                 ...    ...
# 2009  At a volume setting of half or less, the speak...      0
# 2472  Nope. Still a lot to be improved. For most of ...      0
# 2782  I like having more Alexa devices in my house a...      1
# 2672  Got this for my 2nd Echo in the house, I alrea...      1
# 491                           I've already returned it.      0
#
#                                           clean_reviews pred_label
# 2005  why do we need to buy 100 hub to get it to wor...
# 2439  seems to work ok but no youtube tv really can ...
# 2628
# 1379  bought the spot and loved it within months it ...
# 1036                               alexa hardly came on
# ...                                                 ...        ...
# 2009  at volume setting of half or less the speaker ...
# 2472  nope still lot to be improved for most of the ...
# 2782  like having more alexa devices in my house and...
# 2672  got this for my 2nd echo in the house already ...
# 491                              ve already returned it
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 50

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])  # Append batches instead of assigning

# %% [markdown]
# ### Batching API Calls: Gemini API

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 380    Six words, &#34;Alexa, tell me a poop joke.&#34;      1
# 395                         Great Product fast shipping      1
# 1931  The alexa is awesome but when i rcieved the li...      0
# 993   It's extremely useful in simple things like sp...      1
# 735   My husband likes being able to use it to liste...      1
# ...                                                 ...    ...
# 553                  Love these guys they work so great      1
# 1593  Echo Show is said to work with certain apps bu...      0
# 1493                                        Easy set up      1
# 510   Happy with this as I was with the other 2 I or...      1
# 1563  It's like having another kid in the house; I h...      0
#
#                                           clean_reviews pred_label
# 380             six words 34 alexa tell me poop joke 34
# 395                         great product fast shipping
# 1931  the alexa is awesome but when rcieved the ligh...
# 993   it extremely useful in simple things like spot...
# 735   my husband likes being able to use it to liste...
# ...                                                 ...        ...
# 553                  love these guys they work so great
# 1593  echo show is said to work with certain apps bu...
# 1493                                        easy set up
# 510     happy with this as was with the other 2 ordered
# 1563  it like having another kid in the house have t...
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 25

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])  # Append batches instead of assigning

# %%
import time

def gemini_completion_function(batch,current_batch,total_batch):
  """Function works in three steps:
  # Step-1: Convert the DataFrame to JSON using the to_json() method.
  # Step-2: Preparing the Gemini Prompt
  # Step-3: Calling Gemini API
  """

  print(f"Now processing batch#: {current_batch+1} of {total_batch}")

  json_data = batch[['clean_reviews','pred_label']].to_json(orient='records')

  prompt = f"""You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
  Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
  Customer reviews are provided between three backticks below.
  In your output, only return the Json code back as output - which is provided between three backticks.
  Your task is to update predicted labels under 'pred_label' in the Json code.
  Don't make any changes to Json code format, please.
  Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).

  ```
  {json_data}
  ```
  """

  print(prompt)
  response = model.generate_content(prompt)
  time.sleep(5)

  return response

# %%
batch_count = len(batches)
responses = []

for i in range(0,len(batches)):
  responses.append(gemini_completion_function(batches[i],i,batch_count))
# Out:
# Now processing batch#: 1 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"six words 34 alexa tell me poop joke 34","pred_label":""},{"clean_reviews":"great product fast shipping","pred_label":""},{"clean_reviews":"the alexa is awesome but when rcieved the light buld did not know that need another adapter to have the light buld to work was not aware of that disappointed","pred_label":""},{"clean_reviews":"it extremely useful in simple things like spotify and audible and things like that but sometimes it doesn answer everything ask but it still nice to use","pred_label":""},{"clean_reviews":"my husband likes being able to use it to listen to music wish we knew all it capabilities","pred_label":""},{"clean_reviews":"bought an echo dot that had been refurbished but its stops whatever function its performing quite often doesn wake up every time randomly turns on but does nothing do not buy refurbished echo dot","pred_label":""},{"clean_reviews":"works fine wanted this for my bedroom television","pred_label":""},{"clean_reviews":"the product is attractive and somewhat useful but amazon chose to force users to view their things to try and trending this greatly depreciates the value of the product do not buy unless you are willing to view billboard from amazon","pred_label":""},{"clean_reviews":"would love this but there is no way to stop the screen from constantly scrolling through things to try if amazon would make this setting would change my review to 5 stars","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"3rd dot love it","pred_label":""},{"clean_reviews":"fan of echo devices think it great alternative to clean clock like using it to adjust the lightning in the room and listening to sounds to help sleep my two year old sleeps so much better with it on we also use it to tell my two year old stories only issue is the volume of alexa speaking when you tell her to turn off the lights is loud when the volume is set to what you want to listen to the music at night","pred_label":""},{"clean_reviews":"like the compact structure of the dot the sound is little too low","pred_label":""},{"clean_reviews":"not all that happy the speaker isn great and for some reason lot of times when play music it will start to make some weird noise and just stop my son has google home and it is much better","pred_label":""},{"clean_reviews":"works great no different than the new ones","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"it is very slow compared to the echo","pred_label":""},{"clean_reviews":"34 never buy certified and refurbished echo dot 34 bought 34 certified and refurbished 34 echo dot this unit is very poor in receiving command and sometimes it does not even acknowledge the command never buy refurbished echo dot the unit received was probably never was certified and refurbished as indicated also bought new echo dot it works perfectly very disappointed","pred_label":""},{"clean_reviews":"initially this echo dot worked very well over time the dot stopped responding to alexa unless you were within one foot of it yelling the other echos echo dots in other rooms would respond without response from this echo dot would not recommend buying refurbished","pred_label":""},{"clean_reviews":"ve only had this week but so far so good we are enjoying it","pred_label":""},{"clean_reviews":"ordered 2 on deal day 1 doesn work and 2 nd just went down after 2 days","pred_label":""},{"clean_reviews":"love it great product","pred_label":""},{"clean_reviews":"fast to load but keeps rebooting in middle of shows","pred_label":""},{"clean_reviews":"have had all good experience so far with the second generation echo there are so many more things to learn but have not had the time yet right now am mostly enjoying the music weather updates using the alarm feature and her personality have also purchased some mini smart socket yes am very excited to begin using them","pred_label":""},{"clean_reviews":"working great and my daughter loves it","pred_label":""}]
#   ```
#
# Now processing batch#: 2 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"the volume is very low","pred_label":""},{"clean_reviews":"was really happy with my original echo so thought get an echo dot to use in my bedroom was really disappointed in the audio quality so connected an external speaker via bluetooth the audio was much better but started having problems with it loosing connection with the wifi presumably due to interference from the bluetooth then connected speaker via the auxiliary jack when did that the auxiliary jack picked up interference from the wifi and was woken up in the middle of the night by horrible buzzing sound im hoping amazon will take this thing back and give me good deal on an echo spot which hope will be better nightstand device","pred_label":""},{"clean_reviews":"it was harder to setup then thought it should be for some reason had to default it twice had to go thru too many steps to setup and find my devices would be nice if it could interact with my xfinity cable tv cable box and it also does not work with my xfinity alarm for my house or my cameras be nice set and disarm the alarm with alexa had to install skill app to setup bulb whats that about you ship it with your product should have said alexa setup bulb or alexa find new bulb and alexa setup nest it fine that you use third party apps but alexa should do the work for you","pred_label":""},{"clean_reviews":"fun","pred_label":""},{"clean_reviews":"love alexa these are the best thing have ever bought don know how ever lived with out these things amazing so happy with this product just wish it would use google to","pred_label":""},{"clean_reviews":"the only negative we have on this product is the terrible sound quality massive difference from the alexa which to us was big reason we wanted to purchase this won be buying another until the speaker and sound quality can improve","pred_label":""},{"clean_reviews":"like how it will connect to bluetooth without an adapter like the google only reason for 4 stars is volume level without external speaker easy to use","pred_label":""},{"clean_reviews":"bought this to replace sony dash remember those after sony decided to pull support from it entirely it works great for what use it for an alarm clock weather station background music player and voice control of lights throughout my house my biggest gripe about the device and why knocked star off is that you can turn off the suggestions on 34 things to try 34 it an annoying and stupid design decision since you have control to turn off other things you don want to see as it cycles through content screens software update or two would help this improve especially full control of what we want and don want to see in the content rotation","pred_label":""},{"clean_reviews":"no youtube","pred_label":""},{"clean_reviews":"stopped working after 2 weeks didn follow commands really fun when it was working","pred_label":""},{"clean_reviews":"bought this for myself and didn realize it had to be plugged in just to work it isn convenient to make them always have to connect to wall it should ve been more clear when bought it","pred_label":""},{"clean_reviews":"no you tube wouldn have bought it if known that","pred_label":""},{"clean_reviews":"got this for my 2nd echo in the house already have the regular echo the echo dot was easy to set up but the sound is not enjoyable wishing would have just gone with another regular echo solely based on sound","pred_label":""},{"clean_reviews":"love my echo spot","pred_label":""},{"clean_reviews":"reached out to amazon because the device wanted to sync my phone number but it would not allow because it said my number was already in use customer service couldn help they basically told me to contact sprint to assist so echo does the bare minimum without access to my phone for set up so its kind of pointless to have and pay for","pred_label":""},{"clean_reviews":"wanted to use this as bedside clock with the ability to play music and podcasts sadly it continuously scrolls the 34 things to try 3 ...
#   ```
#
# Now processing batch#: 3 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"works fine just realize don need this because don use it","pred_label":""},{"clean_reviews":"love it now if can only find the correct smart links plug to connect this too","pred_label":""},{"clean_reviews":"loved it","pred_label":""},{"clean_reviews":"as always easy to set up","pred_label":""},{"clean_reviews":"love you so much","pred_label":""},{"clean_reviews":"for the price the product is nice quality and has few nice features so definitely no complaints there the reason why only gave it 3 stars is because the echo dot is not what thought it was going to be so that may just be buyer error first didn know that the product has to be plugged in at all times to work so really don like that it not stand alone device also the speaker is not very loud so if you are buying it as bluetooth speaker don lastly sure the echo dot can do lot but haven quite figured out how to use it fully but it just kind of seems like an unnecessary device to own plus setting it up was awful would definitely save the money and buy the nicer one that is actually alexa","pred_label":""},{"clean_reviews":"this was an impulse buy but turns out really enjoy my new dot my grands love requesting songs and playing games like listening to my audible selection keeping up with my to do lists and discovering new alexa skills fun and practical my echo dot has been surprisingly welcome addition to my home","pred_label":""},{"clean_reviews":"it ok the speaker is pretty terrible google home is better product","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"we are very pleased with this item the display is clean and crisp and easy to read we enjoy trying the suggested things to try asking alexa we use the timer feature quite bit and have added our calendars and contacts we are still exploring the many skills available","pred_label":""},{"clean_reviews":"invasive and scared the crap out of me for speaking when it was not spoken to creapy af","pred_label":""},{"clean_reviews":"perfect for home office","pred_label":""},{"clean_reviews":"awesome life changer seriously am able to start my morning with alexa by having her 34 wake 34 me up with her alarm and then playing me some music she has gotten used to my voice that can be in another room and she will 34 listen 34 to what say love both my echos don hesitate get one and for the price the speaker is unbelievable am buying the cordless holder so can take the echo anywhere love my purchase and love alexa","pred_label":""},{"clean_reviews":"device was not working followed all instructions for alexa echo dot and it did not come on very upsetting","pred_label":""},{"clean_reviews":"too difficult to set up it keeps timing out before you can enter the password","pred_label":""},{"clean_reviews":"it got great sound and bass but it doesn work all of the time its still hot or miss when it recognizes things","pred_label":""},{"clean_reviews":"it does not pick up my voice unless yell most times","pred_label":""},{"clean_reviews":"didn like that almost everytime asked alexa question she would say dont know that or havent learned that","pred_label":""},{"clean_reviews":"returnef this item because it does not speak spanish","pred_label":""},{"clean_reviews":"always wanted one till got one it not at all what it cracked up to be it hard to navigate actually like the dot better","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"this device does not interact with my home filled with apple devices how disappointing","pred_label":""},{"clean_reviews":"am impressed with the sound quality","pred_label":""},{"clean_reviews":"returned from repair with no repair done it has problem which requires it to be on for while for the defective part to show itself sent it for repair and got it back without being fixed the site gives no option to complain from the page have echo spot which works perfectly in the same position","pred_label":""}]
#   ```
#
# Now processing batch#: 4 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"fairly useless","pred_label":""},{"clean_reviews":"barry","pred_label":""},{"clean_reviews":"am having real difficulty working with the echo dot alexi is not very smart 9 out of 10 questions have asked get the 34 not sure 34 half the time am still asking the question and alexi is saying 34 not sure 34 the music is great and works well for that all in all so far it been very frustrating experience","pred_label":""},{"clean_reviews":"having so much fun with alexa love being able to listen to music when across the room or busy doing something else","pred_label":""},{"clean_reviews":"alexa is pretty dumb","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"nice product","pred_label":""},{"clean_reviews":"love alexa love the echo dot but we have trouble with the speakers when using the intercom","pred_label":""},{"clean_reviews":"used twice not working","pred_label":""},{"clean_reviews":"this was my 4th echo device 1st echo show it seemed to have huge potential and really wanted to like it but soon found out it is quite limited bit disappointing but not the end of the world used it like use my other screenless echos for little under 2 month when the screen started flickering mostly on the bottom of the screen but not just quick look in some forums made me understand it is pointless asking for replacement as some people had 2 3 devices replaced only to start flickering again shortly after amazon are not providing any serious answers and this has been going on for quite some time apparently long story short moved it to the hallway and been using it as very expensive and bulky voice activated light switch for my hue lights so like the headline suggests meh","pred_label":""},{"clean_reviews":"alexa didn know answers to many questions we asked for example we asked how many cups in pound and she said pound is form of money","pred_label":""},{"clean_reviews":"no it is broke and can get help fixing or replacing it","pred_label":""},{"clean_reviews":"the product sounded the same as the emoji speaker from five below my sister has and even that one has bluetooth and doesn need to be plugged in the only good thing about this is that you can speak to it","pred_label":""},{"clean_reviews":"great addition to the alexa family just wish it could use the screen more than backgrounds don get me wrong don regret buying it especially for the primeday sale of 100 off sale price but for now the skills for the show are lacking","pred_label":""},{"clean_reviews":"love my new echo dot right now mainly use it to play music at night but it gets the job done","pred_label":""},{"clean_reviews":"unit came with the wrong plug will have to send back to amazon","pred_label":""},{"clean_reviews":"ll be returning it it been nothing but annoying the hub can be turned off if not needed and it interferes with my hue bridge can even install philips lights with it unless unplug it to do so there are plenty of other reviews that go in depth with the issues bottom line is it sucks as hub it doesn support wave and zigbee which in fairness knew in advance but when the one protocol it does support doesn do many functions that dedicated one will what the point noticed right away that my philips hue bridge supports firmware upgrades to the light bulbs themselves and this doesn found that rather interesting","pred_label":""},{"clean_reviews":"would love this remote if wasnt spending so much money replacing the batteries its upsetting that spent money on such great device all for the batteries not to last","pred_label":""},{"clean_reviews":"from such small speaker it sounds great","pred_label":""},{"clean_reviews":"easy to set up still trying to get it to connect to light bulb smart plug grandkids think alex is cool","pred_label":""},{"clean_reviews":"love these guys they work so great","pred_label":""},{"clean_reviews":"echo show is said to work with certain apps but not cozi state works with echo show but the cozi family doesn very well a ...
#   ```

# %%
import json

df_total = pd.DataFrame()  # Initialize an empty DataFrame

for response in responses:
    # Clean the data by stripping the backticks
    json_data = response.text.strip("`")

    # Load the cleaned data and convert to DataFrame
    data = json.loads(json_data)
    df_temp = pd.DataFrame(data)

    # Concatenate the DataFrame to the final DataFrame
    df_total = pd.concat([df_total, df_temp], ignore_index=True)

print(df_total)  # Display the final DataFrame
# Out:
#                                         clean_reviews  pred_label
# 0             six words 34 alexa tell me poop joke 34           0
# 1                         great product fast shipping           1
# 2   the alexa is awesome but when rcieved the ligh...           0
# 3   it extremely useful in simple things like spot...           1
# 4   my husband likes being able to use it to liste...           1
# ..                                                ...         ...
# 95                 love these guys they work so great           1
# 96  echo show is said to work with certain apps bu...           0
# 97                                        easy set up           1
# 98    happy with this as was with the other 2 ordered           1
# 99  it like having another kid in the house have t...           0
#
# [100 rows x 2 columns]

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_total['pred_label'] = df_total['pred_label'].values
test_set_total
# Out:
#                                                  review  label  \
# 380    Six words, &#34;Alexa, tell me a poop joke.&#34;      1
# 395                         Great Product fast shipping      1
# 1931  The alexa is awesome but when i rcieved the li...      0
# 993   It's extremely useful in simple things like sp...      1
# 735   My husband likes being able to use it to liste...      1
# ...                                                 ...    ...
# 553                  Love these guys they work so great      1
# 1593  Echo Show is said to work with certain apps bu...      0
# 1493                                        Easy set up      1
# 510   Happy with this as I was with the other 2 I or...      1
# 1563  It's like having another kid in the house; I h...      0
#
#                                           clean_reviews  pred_label
# 380             six words 34 alexa tell me poop joke 34           0
# 395                         great product fast shipping           1
# 1931  the alexa is awesome but when rcieved the ligh...           0
# 993   it extremely useful in simple things like spot...           1
# 735   my husband likes being able to use it to liste...           1
# ...                                                 ...         ...
# 553                  love these guys they work so great           1
# 1593  echo show is said to work with certain apps bu...           0
# 1493                                        easy set up           1
# 510     happy with this as was with the other 2 ordered           1
# 1563  it like having another kid in the house have t...           0
#
# [100 rows x 4 columns]

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix

y_true = test_set_total["label"]
y_pred = test_set_total["pred_label"]

confusion_matrix(y_true, y_pred)
# Out:
# array([[51,  1],
#        [ 6, 42]])
